# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivendrahappy/Python-for-CS-MIT-OCW/blob/main/MITOCW_60001_Python_Lec_2_branching_iteration_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hi= "Hello there"
name= "Ana"
greet=(hi + name)
print(greet)
# Out:
# Hello thereAna

# %% [markdown]
# for space bet there and Ana use " " space

# %%
hi= "Hello there"
name= "Ana"
greet=(hi+" "+name)
print(greet)
# Out:
# Hello there Ana

# %% [markdown]
# Name 3 times by *

# %%
hi= "Hello there"
name= "Ana"
silly=hi+(" "+name)*3
print(silly)
# Out:
# Hello there Ana Ana Ana

# %% [markdown]
# COMMAS CREATES SPACE WHILE + CONTINUE WITHOUT SPACE

# %%
x=1
print(x)
# Out:
# 1

# %% [markdown]
# using comma which creates space

# %%
x=5
print("my fav number is",x)
# Out:
# my fav number is 5

# %% [markdown]
# using + thats don't creates space but it needs x_str instead of x

# %%
x=5
x_str = str(x)
print("my fav number is" + x_str)
# Out:
# my fav number is5

# %% [markdown]
# MITOCW assignment

# %%
x=1
print(x)
x_str = str(x)
print("my fav number is ",x, ".", "x=",x)
print("my fav number is",x_str + "." + "x=" + x_str)
print("my fav number is " + x_str + "." + "x="+x_str)
# Out:
# 1
# my fav number is  1 . x= 1
# my fav number is 1.x=1
# my fav number is 1.x=1

# %% [markdown]
# Input(user Input)

# %%
text=("type anything...")
print(5*text)
# Out:
# type anything...type anything...type anything...type anything...type anything...
