# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivendrahappy/Python-for-CS-MIT-OCW/blob/main/MITOCW6_0001pythonday1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MITOCW 6.0001 Intro to CS in Python ,Lec 1 What is Computation By Proff. Ana Bell

# %%
print(5+2)
# Out:
# 7

# %%
print(5+3)
# Out:
# 8

# %%
x=5
y=6
print(x+y)
# Out:
# 11

# %%
5+3
# Out:
# 8

# %% [markdown]
# This is just numeric example

# %%
x=5
y=10
print(x+y)
# Out:
# 15

# %% [markdown]
# This is algebra

# %%
3+2
# Out:
# 5

# %%
print(3+2)
# Out:
# 5

# %%
5-2
# Out:
# 3

# %% [markdown]
# Int(integers)

# %%
3.14
2.0
-0.5
# Out:
# -0.5

# %% [markdown]
# Float(real Numbers) Numbers with decimals

# %%
True
False
# Out:
# False

# %% [markdown]
# bool(Boolean) only 2 values

# %%
x=5
print(float(x))
# Out:
# 5.0

# %% [markdown]
# Float are numbers

# %%
y=3.17
print(int(y))
# Out:
# 3

# %% [markdown]
# Intgers

# %%
print(str(10))
# Out:
# 10

# %% [markdown]
# String 10

# %%
5+int("3")
# Out:
# 8

# %% [markdown]
# DATE- MARCH-25-2026

# %%
pi=3.14159
radius= 2.2
area= pi*(radius**2)
print(area)
# Out:
# 15.205295600000001

# %% [markdown]
# * multiply ** power.**2 means 2 times power

# %%
x=5
x=x+1
print(x)
# Out:
# 6

# %%
radius=2.2
print(radius+1)
# Out:
# 3.2

# %% [markdown]
# Changing Bindings of variables

# %%
radius=2.2
print(radius+1)
# Out:
# 3.2

# %% [markdown]
# Area does not change automatically.For new radius ,we calculate again

# %%
radius=3.3
area=pi*(radius**2)
print(area)
# Out:
# 34.21191509999999

# %% [markdown]
# LECTURE 2 STRING AND ITERATION

# %% [markdown]
# String * number = repeats text
# num*num= does multiplication

# %% [markdown]
# input()= gives string (text)
# int(input())=gives number(for math)

# %%
text=input("type anuthing")
print(5*text)
# Out:
# type anuthinghi
# hihihihihi

# %%
num = int(input("type a number"))
print(5*num)
# Out:
# type a number4
# 20

# %% [markdown]
# Direct case ,no int, input ,because we are not using input

# %%
num = 4
print(5*num)
# Out:
# 20

# %% [markdown]
# Comparison Operator

# %%
"a" > "b"
# Out:
# False

# %%
"a" > 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1010/2347636830.py in <cell line: 0>()
# ----> 1 "a" > 5
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# python don't know to add a string to an integer

# %% [markdown]
# Control Flow (decesion making)   if

# %%
x = 5
if x > 3:
    print("x is greater than 3")
# Out:
# x is greater than 3

# %% [markdown]
# space(indentation) before print because python needs it to understand blocks if creats a block

# %%
x = 2
if x > 3 :
    print("x is greater than 3")
else:
    print("x is not greater than 3")
# Out:
# x is not greater than 3

# %% [markdown]
# 2> 3  is false
# So, else block runs

# %%
x = 0
if x  > 0:
  print("positive")
elif x < 0:
  print("negative")
else:
  print("zero")
# Out:
# zero

# %% [markdown]
# Only last case is true thats why zero

# %%
x = float(input("enter a number for x:"))
y = float(input("enter a number for y:"))
if x == y:
  print("x and y are equal")
  if y != 0:
    print("therefore,x/y is",x/y)
elif x < y:
  print("x is smaller")
else:
  print("y is smaller")
# Out:
# enter a number for x:2
# enter a number for y:5
# x is smaller

# %%
n = 0
while n < 5:
  print(n)
  n = n+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
n = input ("You're lost in the forest.Go left or right ? ")
while n == "right":
  n = input("You are in the lost forest.Go left or right ?")
print("You got out of the lost forest")
# Out:
# You're lost in the forest.Go left or right ? right
# You are in the lost forest.Go left or right ?left
# You got out of the lost forest

# %% [markdown]
# n== right means you are lost in forest then left input gives you are out of the forest

# %%
for i in range (5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# for loop , when we know how many times to repeat,loop runs 5 times from 0 to 4

# %%
n = 0
while n<5:
  print (n)
  n = n + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# we repeat until condition becomes false.

# %% [markdown]
# **LECTURE 3 STRING MANIPULATION,GUESS AND CHECK, APROXIMATION , BISECTION**

# %% [markdown]
# 1. Basic string + lenght

# %%
s = "abc"
print (len(s))
# Out:
# 3

# %% [markdown]
# three charecters in s

# %% [markdown]
# 2. Indexing (pick letters)

# %%
s = "abc"
print (s[0])
print (s[2])
# Out:
# a
# c

# %% [markdown]
# when s = 0 = a, because indexing starts from zero.

# %% [markdown]
# 3. Negative indexing(from end)

# %%
s = "abc"
print (s[-1])
# Out:
# c

# %% [markdown]
# last  c = -1

# %% [markdown]
# 4. Slicing ( Part of string)

# %%
s = "abcdef"
print (s[1:4])
# Out:
# bcd

# %% [markdown]
# s= from 1 to 4 , excluding 4

# %% [markdown]
# 5. Reverse String

# %%
s = "abc"
print (s[::-1])
# Out:
# cba

# %% [markdown]
# 6.Full Slice ( copy whole )

# %%
s = "abcdef"
print(s[:])
# Out:
# abcdef

# %% [markdown]
# 7.Step = 2 (Skip Charecters) take every 2nd charecter.

# %%
s = "abcdef"
print(s[::2])
# Out:
# ace

# %% [markdown]
# 8.Reverse String

# %%
s = "abcdef"
print(s[::-1])
# Out:
# fedcba

# %% [markdown]
# 9.Partial Slice from middle ,Start = index 2 , stop= index 5(excluded)

# %%
s = "abcdef"
print(s[2:5])
# Out:
# cde

# %% [markdown]
# 10 . Mix : Start + Step.Start index 1,go till 6 ,jump by 2

# %%
s = "abcdef"
print(s[1:6:2])
# Out:
# bdf

# %% [markdown]
# 23 april 2026

# %%
s = "abcdef"
print(s[1:4])
print(s[::2])
print(s[::-1])
# Out:
# bcd
# ace
# fedcba

# %% [markdown]
# **Immutable String Fix**

# %%
s = "hello"
s = "y" + s[1:]
print(s)
# Out:
# yello

# %% [markdown]
# 1:len(s) or 1: from index 1 to end

# %%
s = "hello"
s = "y" + s[1:len(s)]
print (s)
# Out:
# yello

# %% [markdown]
# **Basic Loop**

# %%
for var in range (4):
  print (var)
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# confirms loop runs 4 times starts from 0

# %%
for var in range (4,6):
  print (var)
# Out:
# 4
# 5

# %% [markdown]
# start from 4 and stop before 6

# %%
for ch in "abc":
  print(ch)
# Out:
# a
# b
# c

# %% [markdown]
# Date 24 April 2026

# %%
word = "abc"
for char in word :
  print (char)
# Out:
# a
# b
# c

# %%
word = "dog"
for char in word :
  if char == "o":
    print ("found o")
# Out:
# found o

# %%
word = input ("Enter a word:")
for char in word:
  if char == "i" or char == "u":
    print("there is i or u")
# Out:
# Enter a word:milk
# there is i or u

# %% [markdown]
# milk is the word and from it we get i (milk) only i but there is condition or u , so or u also comes

# %%
an_letters = "aeiou"
word = input ("Enter a word:")
for char in word :
  if char in an_letters:
    print ("give me an " + char)
  else:
    print ( "give me a " + char)
# Out:
# Enter a word:dog
# give me a d
# give me an o
# give me a g

# %% [markdown]
# ALGORITHMS GUESS AND CHECK
# CUBE ROOT

# %%
cube = 8
for guess in range (abs(cube)+1):
  if guess**3 >= abs (cube):
    break

if guess **3 != abs (cube):
  print(cube,"is not a perfect cube")

else :
  if cube < 0:
    guess = -guess
  print("cube root of",cube,"is", guess)
# Out:
# cube root of 8 is 2

# %%
cube = 27
epsilon = 0.01
num_guesses = 0
low = 0
high = cube
guess = (high + low)/2.0
while abs(guess**3 - cube) >= epsilon:
  if guess**3 < cube :
    low = guess
  else:
    high = guess
  guess = (high + low)/2.0
  num_guesses += 1
print ("num_guesses =",num_guesses)
print (guess,"is close to the cube root of",cube)
# Out:
# num_guesses = 14
# 3.000091552734375 is close to the cube root of 27

# %% [markdown]
# Bisection method

# %%
cube = 27
epsilon = 0.01
num_guesses = 0

low = 0
high = cube

guess = (high + low)/2.0
while abs(guess**3 - cube) >= epsilon:
  if guess**3 < cube :
    low = guess
  else:
    high = guess
  guess = (high + low)/2.0
  num_guesses += 1
print ("num_guesses =",num_guesses)
print (guess,"is close to the cube root of",cube)
# Out:
# num_guesses = 14
# 3.000091552734375 is close to the cube root of 27

# %% [markdown]
# **CHAPTER  4 DECOMPOSITION< ABSTRACTION AND FUNCTION**
#
# FUNCTION 20 MAY 2026

# %%
def square(x) :
  return x*x

print (square(5))
# Out:
# 25

# %%
def is_even (i):
  return i%2 == 0

print(is_even (4))
print(is_even(5))
# Out:
# True
# False

# %% [markdown]
# VARIABLE SCOPE

# %%
def f(x) :
  x = x + 1
  print ( 'in f(x): x= ',x)
  return x

x = 3
z = f(x)
print ("outside x =",x)

print (" z=",z)
# Out:
# in f(x): x=  4
# outside x = 3
#  z= 4

# %% [markdown]
# Revision about inside and outside ,Date 4 June 2026.

# %%
def square (x):
  return x*x
print (square (5))
# Out:
# 25

# %%
def square (x):
  return x*x

y = square(8)
print(y)
# Out:
# 64

# %%
def square (x):
 return x*x
a= square (3)
b= square (4)

print (a)
print (b)
# Out:
# 9
# 16

# %% [markdown]
# Without RETURN

# %%
def square (x):
  x*x

y = square (5)
print (y)
# Out:
# None

# %%
def square (x):
  return x*x
y = square(5)
print(y)
# Out:
# 25

# %%
def square (x):
  x*x
y = square (5)
print(y)
# Out:
# None

# %% [markdown]
# A FUNCTION CAN BE PASSED INTO ANOTHER FUNCTION/ FUNCTION AS ARGUMENT

# %%
def hello ():
  print ("hello")

def run(f):
  return f()
run(hello)
# Out:
# hello

# %%
def make_pizza():
  print ("pizza")

food = make_pizza()
print(food)
# Out:
# pizza
# None

# %%
def make_pizza():
  return "pizza"
food = make_pizza()
print(food)
# Out:
# pizza

# %%
def func_a ():
  print('inside func_a')


def func_b(y):
  print ('inside func_b')
  return y

def func_c(z_callable):
  print('inside func_c')
  return z_callable()

print (func_a())
print (5 + func_b(2))

print (func_c(func_a))
# Out:
# inside func_a
# None
# inside func_b
# 7
# inside func_c
# inside func_a
# None

# %% [markdown]
# **CHAPTER 5 TUPLES<LISTS,ALIASING< MUTABILITY ,CLONING**

# %%
te = ()
print (te)
# Out:
# ()

# %% [markdown]
# EMpty tuple

# %%
t = (2, "mit",3)
print (t)
# Out:
# (2, 'mit', 3)

# %% [markdown]
# 2 create tuple

# %%
t = (2,"mit" ,3)
print(t[0])
# Out:
# 2

# %% [markdown]
# Access first element.

# %%
t = (2,"mit",3)
print(t[1:2])
# Out:
# ('mit',)

# %%
t = (2,"mit",3)
print(t[0:2])
# Out:
# (2, 'mit')

# %% [markdown]
# 0 to one before 2

# %%
t = (2,"mit",3)
print(t +(5,6))
# Out:
# (2, 'mit', 3, 5, 6)

# %%
t = (2,"mit",3)
print(len(t))
# Out:
# 3

# %% [markdown]
# how many elements inside t

# %%
x = 5
y = 10

(x,y) = (y,x)
print(x)
print (y)
# Out:
# 10
# 5

# %% [markdown]
# Above swap values

# %%
def quotient_and_remainder (x,y):
  q = x // y
  r = x % y
  return (q,r)
print (quotient_and_remainder(17,5))
# Out:
# (3, 2)

# %% [markdown]
# above ,return two values.

# %%
def quotient_and_remainder (x,y):
  q = x // y
  r = x % y
  return (q,r)
(quot,rem) = quotient_and_remainder(17,5)
print(quot)
print(rem)
# Out:
# 3
# 2

# %% [markdown]
# Above, we stored both value.

# %% [markdown]
# TUPLE ,INDEX , VARIABLE.

# %%
t = (8,'MIT')
print (t[0])
print (t[1])
# Out:
# 8
# MIT

# %%
t = (8, "MIT")
print(t[0])
print(t[1])
# Out:
# 8
# MIT

# %% [markdown]
# TEST

# %%
test = (1,"a"),(2,"b"),(1,"a"),(7,"b")
for t in test:
  print(t)
# Out:
# (1, 'a')
# (2, 'b')
# (1, 'a')
# (7, 'b')

# %%
test = (1,"a"),(2,"b"),(1,"a"),(7,"b")
for t in test :
  print(t[0])
# Out:
# 1
# 2
# 1
# 7

# %%
test = (1,"a"),(2,"b"),(1,"a"),(7,"b")
for t in test :
  print(t[1])
# Out:
# a
# b
# a
# b

# %%
test = (10,"PYTHON"),(20,"MIT"),(30,"AI")
for t in test:
  print(t)
  print(t[0])
  print(t[1])
# Out:
# (10, 'PYTHON')
# 10
# PYTHON
# (20, 'MIT')
# 20
# MIT
# (30, 'AI')
# 30
# AI

# %% [markdown]
# 13 July 2026

# %%
t = (9,"AI")
print(t[0])
print(t[1])
# Out:
# 9
# AI

# %% [markdown]
# Q- Predict the final value of the nums

# %%
nums = ()
t = (7,"Python")
nums = nums + (t[0],)
print (nums)
# Out:
# (7,)

# %% [markdown]
# Q- Predict the final value of the words

# %%
words = ()
t = (7,"Python")
words = words + (t[1],)
print (words)
# Out:
# ('Python',)

# %% [markdown]
# Q- Will the if statement execute?

# %%
words = ("MIT",)
t = (5,"MIT")
if t[1] not in words:
  words = words + (t[1],)
print (words)
# Out:
# ('MIT',)

# %% [markdown]
# Q- Predict the final value of both variable

# %%
test=(
     (1, "A"),
     (2, "B"),
     (3, "A")
)

nums = ()
words = ()
for t in test:
  nums = nums + (t[0],)
  if t[1] not in words:
    words = words + (t[1],)
  print (nums)
  print (words)
# Out:
# (1,)
# ('A',)
# (1, 2)
# ('A', 'B')
# (1, 2, 3)
# ('A', 'B')

# %% [markdown]
# Practice min() and max()

# %%
nums = (15,2,9,21,6)
print(min(nums))
print (max(nums))
# Out:
# 2
# 21

# %% [markdown]
# Sum using Index

# %%
L = [3,7,9]
total= 0
for i in range(len(L)):
  total += L[i]
print(total)
# Out:
# 19

# %% [markdown]
# Sum Using values

# %%
L = [3,7,9]
total = 0
for i in L:
  total += i
  print(total)
# Out:
# 3
# 10
# 19

# %% [markdown]
# Remove ()

# %%
L = [1,2,3,2,5]
L.remove(2)
print(L)
# Out:
# [1, 3, 2, 5]

# %% [markdown]
# del

# %%
L = [10,20,30,40]
del(L[1])
print(L)
# Out:
# [10, 30, 40]

# %% [markdown]
# pop ()

# %%
L= [5,10,15,20]
x = L.pop()
print(x)
print(L)
# Out:
# 20
# [5, 10, 15]

# %% [markdown]
# for chatbot

# %%
memory = []
memory.append("Hello")
memory.append("I like AI")
memory.append("TOEFL")
memory.pop()
print(memory)
# Out:
# ['Hello', 'I like AI']

# %% [markdown]
# Date- 12-08-2026
#
# del()

# %%
L = [2,1,3,6,3,7,0]
del(L[1])
print(L)
# Out:
# [2, 3, 6, 3, 7, 0]

# %% [markdown]
# 2. String -List

# %%
s = "I<3 cs"
L=list (s)
print(L)
# Out:
# ['I', '<', '3', ' ', 'c', 's']

# %% [markdown]
# Split

# %%
s = "I<3 cs"
print(s.split("<"))
# Out:
# ['I', '3 cs']

# %% [markdown]
# Join()

# %%
L = ['a','b','c']
print(''.join(L))
print('_'.join(L))
# Out:
# abc
# a_b_c

# %% [markdown]
# CLoning with [:]
# cool makes the copy of the list.

# %%
cool = [1,2,3]
chill = cool [:]
chill.append(4)
print(cool)
print(chill)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %% [markdown]
# Nested List

# %%
cool = ['Blue','green']
warm = ['Red','Yellow','Orange']
colors1 = [cool]
colors1.append(warm)
print(colors1)
# Out:
# [['Blue', 'green'], ['Red', 'Yellow', 'Orange']]

# %% [markdown]
# The nested list Mutation

# %%
cool = ['blue','green']
warm = ['red','yellow','orange']
colors1 = [cool]
colors1.append(warm)
print(colors1)

warm.remove ('red')
print(warm)
print(colors1)
# Out:
# [['blue', 'green'], ['red', 'yellow', 'orange']]
# ['yellow', 'orange']
# [['blue', 'green'], ['yellow', 'orange']]

# %% [markdown]
# Nested iteration

# %%
cool = ['blue','green']
warm = ['red','yellow','orange']
colors1 = [cool]
colors1.append(warm)

for e in colors1:
  print('e=',e)
# Out:
# e= ['blue', 'green']
# e= ['red', 'yellow', 'orange']

# %%
cool = ['blue','green']
warm = ['red','yellow','orange']
flat = cool + warm
print(flat)
# Out:
# ['blue', 'green', 'red', 'yellow', 'orange']

# %% [markdown]
# Sorting  a list with short()

# %%
flat = [ 'yellow','blue','red','green']
flat.sort()
print(flat)
# Out:
# ['blue', 'green', 'red', 'yellow']

# %% [markdown]
# Shorting with sorted()

# %%
flat = ['yellow','blue','red','green']
new_flat = sorted(flat,reverse=True)
print('flat=',flat)
print('new_flat=',new_flat)
# Out:
# flat= ['yellow', 'blue', 'red', 'green']
# new_flat= ['yellow', 'red', 'green', 'blue']

# %% [markdown]
# Chapter 6
#
# Topic 1                       Recurssion

# %%
def mult(a,b):
  if b == 1 :
    return a
  else:
    return a + mult(a,b-1)
print(mult(5,4))
# Out:
# 20

# %% [markdown]
# Topic 2 Recursive factorial

# %%
def fact (n):
  if n == 1:
    return 1
  else:
    return n *fact(n-1)
print(fact(4))
# Out:
# 24

# %% [markdown]
# Dictionaries

# %%
my_dic = {}
grades = {'Ana':'B','John':'A+','Denise':'A','Katty':'A'}
print (grades['John'])
# print (grades['Sylvan']) # This would also cause a KeyError because 'Sylvan' is not in the dictionary.
# Out:
# A+

# %% [markdown]
# Adding missing key
# ['Sylvan'] = 'A'

# %%
my_dic = {}
grades = {'Ana':'B','John':'A+','Denise':'A','Katty':'A'}
grades['Sylvan'] = 'A'
print(grades)
# Out:
# {'Ana': 'B', 'John': 'A+', 'Denise': 'A', 'Katty': 'A', 'Sylvan': 'A'}

# %%
my_dic = {}
grades = {'Ana':'B','John':'A+','Denise':'A','Katty':'A'}
grades['Sylvan'] = 'A'
print(grades['John'])
print(grades['Sylvan'])
# Out:
# A+
# A

# %% [markdown]
# 3. Updating a existing key

# %%
grades = {'Ana':'B','John':'A+','Denise':'A','Katty':'A'}
grades['John'] = 'B'
print(grades)
# Out:
# {'Ana': 'B', 'John': 'B', 'Denise': 'A', 'Katty': 'A'}

# %% [markdown]
# 4. Checking whether a key exists

# %%
grades = {'Ana':'B','John':'A+','Denise':'A','Katty':'A'}
print ('John' in grades)
print ('Alex' in grades)
# Out:
# True
# False

# %% [markdown]
# 5. Deleting a Key

# %%
grades = {'Ana':'B','John':'A+','Denise':'A','Katty':'A'}
del grades['Ana']
print(grades)
# Out:
# {'John': 'A+', 'Denise': 'A', 'Katty': 'A'}

# %% [markdown]
# 6. getting all keys grades.keys()

# %%
grades = {'Ana':'B','John':'A+','Dennis':'A','Katy':'A'}
print(grades.keys())
# Out:
# dict_keys(['Ana', 'John', 'Dennis', 'Katy'])

# %% [markdown]
# 7. Getting all the values- grades.value()

# %%
grades = {'Ana':'B','John':'A','Dennis':'A','Katy':'A'}
print(grades.values())
# Out:
# dict_values(['B', 'A', 'A', 'A'])

# %% [markdown]
# 8. Dictionaries keys vs. Values

# %%
d = {
    4:{1:0},
    (1,3) : "twelve",
    'const':[1,2,3]
}
print(d[4])
print(d[(1,3)])
print(d['const'])
# Out:
# {1: 0}
# twelve
# [1, 2, 3]

# %% [markdown]
# Using a dictoinary to solve a real world problem

# %% [markdown]
# Step 1 starting a empty frequency dictionary

# %%
freq = {}
print(freq)
# Out:
# {}

# %% [markdown]
# Step 2 Add the first word  eg. apple

# %%
freq = {}
freq['apple'] = 1
print (freq)
# Out:
# {'apple': 1}

# %% [markdown]
# Step -3 Add one more element eg banana

# %%
freq = {}
freq ['apple'] = 1
freq ['banana'] = 1
print(freq)
# Out:
# {'apple': 1, 'banana': 1}

# %% [markdown]
# Step 4 . Increase one mmore existing frequecy ,eg one more banana

# %%
freq = {}
freq ['apple'] = 1
freq ['banana'] = 1
freq ['apple'] = freq ['apple'] + 1
print(freq)
# Out:
# {'apple': 2, 'banana': 1}

# %% [markdown]
# Same idea with +=

# %%
freq = {}
freq ['apple'] = 1
freq ['banana'] = 1
freq ['apple'] +=1
print(freq)
# Out:
# {'apple': 2, 'banana': 1}

# %% [markdown]
# Functions to analyze song lyrics

# %%
def lyrics_to_frequencies(lyrics):
  myDict = {}
  for word in lyrics:
    if word in myDict:
      myDict[word] += 1
    else:
      myDict[word] = 1
  return myDict

lyrics = [ 'love','you','love','baby']
freqs = lyrics_to_frequencies(lyrics)
print(freqs)
# Out:
# {'love': 2, 'you': 1, 'baby': 1}
